# %% [markdown]
# <a href="https://colab.research.google.com/github/dadelani/ALFA/blob/master/PAIDeF_AI4D_topic_classification_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text classification [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dadelani/NLP_DL_Intro/blob/main/PAIDeF_AI4D_topic_classification_notebook.ipynb)
